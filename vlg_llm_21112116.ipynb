# %%
import numpy as np
import re
import pandas as pd
import spacy
import string
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
import nltk
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import seaborn as sns

# %%
nltk.data.path.append("/kaggle/input/nltk-data/nltk-data")

# %%
train_essays_df = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/train_essays.csv")
display(train_essays_df)

train_essays_df['generated'].value_counts()

train_essays_df[train_essays_df['generated']==1]
# Out:
#             id  prompt_id                                               text  \
# 0     0059830c          0  Cars. Cars have been around since they became ...
# 1     005db917          0  Transportation is a large necessity in most co...
# 2     008f63e3          0  "America's love affair with it's vehicles seem...
# 3     00940276          0  How often do you ride in a car? Do you drive a...
# 4     00c39458          0  Cars are a wonderful thing. They are perhaps o...
# ...        ...        ...                                                ...
# 1373  fe6ff9a5          1  There has been a fuss about the Elector Colleg...
# 1374  ff669174          0  Limiting car usage has many advantages. Such a...
# 1375  ffa247e0          0  There's a new trend that has been developing f...
# 1376  ffc237e9          0  As we all know cars are a big part of our soci...
# 1377  ffe1ca0d          0  Cars have been around since the 1800's and hav...
#
#       generated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1373          0
# 1374          0
# 1375          0
# 1376          0
# 1377          0
#
# [1378 rows x 4 columns]
#             id  prompt_id                                               text  \
# 704   82131f68          1  This essay will analyze, discuss and prove one...
# 740   86fe4f18          1  I strongly believe that the Electoral College ...
# 1262  eafb8a56          0  Limiting car use causes pollution, increases c...
#
#       generated
# 704           1
# 740           1
# 1262          1

# %%
nlp = spacy.load("en_core_web_sm")
stop_words = nlp.Defaults.stop_words
punctuations = string.punctuation
print(stop_words)
print(punctuations)
# Out:
# {'mostly', 'over', 'every', 'part', 'across', 'otherwise', 'we', 'am', 'beforehand', 'myself', 'has', 'was', 'made', 'of', '’s', 'such', 'what', 'everyone', 'via', 'call', 'bottom', 'quite', 'may', 'always', 'top', 'well', 'else', 'more', 'thereupon', 'therefore', 'unless', 'became', 'put', 'per', 'forty', 'each', 'three', 'whereby', 'doing', 'throughout', 'will', 'become', 'keep', 'next', 'own', 'whether', 'front', 'they', 'for', 'along', 'them', 'anywhere', 'who', 'when', 'two', 'seem', 'among', 'least', 'about', 'serious', 'nothing', '’m', 'five', 'fifty', 'so', 'its', 'hereby', 'n‘t', 'did', 'due', 'sometimes', 'if', 'becoming', 'be', 'since', 'all', 'around', '’d', 'after', '’re', 'which', 'yourselves', '‘re', 'but', 'once', 'somehow', 'you', 'were', 'except', 'show', 'rather', 'amount', 'everywhere', 'using', 'twelve', 'most', 'further', 'alone', 'several', 'neither', '’ve', 'an', 'eight', 'although', 'say', 'any', 'a', 'already', 'behind', 'various', 'though', 'really', 'last', 'it', 'regarding', 'is', 'becomes', 'through', 'noone', 'hers', 'elsewhere', 'others', 'until', 'either', 'onto', 'namely', 'ourselves', 'before', 'same', 'beside', 'ca', 'full', 'less', 'side', 'with', 'someone', 'itself', 'me', 'why', 'whole', 'now', '‘d', 'thereafter', 'enough', 'hence', 'under', 'as', "n't", 'give', '’ll', 'toward', 'ever', 'this', 'anything', 'yours', 'used', 'too', 'latter', 'does', 'whoever', 'cannot', 'latterly', 'and', 'former', 'would', "'ve", 'towards', 'whereupon', 'where', 'there', 'many', 'first', 'just', 'those', 'might', 'moreover', 'himself', 'being', 'from', 'wherever', 'nobody', 'down', 'have', 'your', '‘ve', 'often', 'themselves', 'beyond', 'hundred', 'up', 'him', "'re", 'anyone', 'much', 'third', 'my', 'besides', 'without', 'whereas', "'d", 'never', '‘ll', 're', 'seeming', 'four', 'had', 'therein', 'by', 'can', 'above', 'nor', 'twenty', 'must', 'while', 'fifteen', 'do', 'against', 'because', 'at', 'few', 'nowhere', 'these', 'whom', 'very', "'m", '‘m', '‘s', 'none', 'thereby', 'she', "'ll", 'hereafter', 'not', 'off', 'herself', 'whatever', 'whereafter', 'amongst', 'make', 'done', 'on', 'ten', 'n’t', 'take', 'should', 'thence', 'together', 'been', 'or', 'anyway', 'during', 'move', 'he', 'that', 'empty', 'in', 'one', 'six', 'i', 'formerly', 'yet', "'s", 'how', 'the', 'sixty', 'meanwhile', 'yourself', 'go', 'both', 'whither', 'our', 'ours', 'upon', 'seems', 'below', 'some', 'still', 'their', 'however', 'again', 'back', 'get', 'thus', 'than', 'even', 'please', 'thru', 'mine', 'nevertheless', 'eleven', 'name', 'between', 'anyhow', 'her', 'then', 'out', 'perhaps', 'nine', 'other', 'no', 'seemed', 'whenever', 'also', 'whose', 'see', 'sometime', 'could', 'almost', 'us', 'hereupon', 'something', 'to', 'here', 'herein', 'within', 'everything', 'wherein', 'are', 'afterwards', 'whence', 'only', 'somewhere', 'his', 'into', 'indeed', 'another'}
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def clean_text(text):
    doc = nlp(text.lower().strip())
    tokens = [word.lemma_ for word in doc if word.text not in stop_words and word.text not in punctuations]
    return " ".join(tokens)

# %%
train_essays_df['cleaned_text'] = train_essays_df['text'].apply(clean_text)

# %%
X = train_essays_df['cleaned_text']
y = train_essays_df['generated']
tfidf = TfidfVectorizer(max_features=5000, min_df=3, max_df=0.7, ngram_range=(1, 2))
X_tfidf = tfidf.fit_transform(X)

# %%
X_tfidf_shuffled, y_shuffled = shuffle(X_tfidf, y, random_state=42)

# %%
class_distribution = train_essays_df['generated'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(class_distribution, labels=class_distribution.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'])
plt.title('Distribution of Class')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(train_essays_df['cleaned_text'].apply(len), bins=50, color='salmon', kde=True)
plt.title('Distribution of Cleaned Text Length')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
model = SVC(probability=True)
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
clf = GridSearchCV(model, parameters, cv=5)

# Fit and Tune Model
clf.fit(X_tfidf_shuffled, y_shuffled)
print("Best Parameters:", clf.best_params_)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Best Parameters: {'C': 1, 'kernel': 'linear'}

# %%
cv_results = pd.DataFrame(clf.cv_results_)

plt.figure(figsize=(10, 6))
sns.heatmap(pd.pivot_table(cv_results, values='mean_test_score', index='param_C', columns='param_kernel'), annot=True, cmap='YlGnBu')
plt.title('Grid Search Mean Test Scores')
plt.show()

# %%
skf = StratifiedKFold(n_splits=5)
accuracies = []
for train_index, test_index in skf.split(X_tfidf_shuffled, y_shuffled):
    X_train, X_test = X_tfidf_shuffled[train_index], X_tfidf_shuffled[test_index]
    y_train, y_test = y_shuffled.iloc[train_index], y_shuffled.iloc[test_index]

    model.set_params(**clf.best_params_)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracies.append(accuracy_score(y_test, y_pred))

print("Average accuracy:", np.mean(accuracies))
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Average accuracy: 0.9978260869565216

# %%
test_df = pd.read_csv('/kaggle/input/llm-detect-ai-generated-text/test_essays.csv')
test_df['cleaned_text'] = test_df['text'].apply(clean_text)
test_tfidf = tfidf.transform(test_df['cleaned_text'])

# %%
y_probs = model.predict_proba(X_tfidf_shuffled)[:, 1]
fpr, tpr, thresholds = roc_curve(y_shuffled, y_probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, color='skyblue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})', marker='o', markersize=8)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.fill_between(fpr, tpr, color='skyblue', alpha=0.2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
submit = pd.read_csv('/kaggle/input/llm-detect-ai-generated-text/sample_submission.csv')
submit['generated'] = model.predict_proba(test_tfidf)[:,1]

submit.to_csv('submission.csv', index=False)

# %%
submit.head()
# Out:
#          id  generated
# 0  0000aaaa   0.005648
# 1  1111bbbb   0.005648
# 2  2222cccc   0.005648
